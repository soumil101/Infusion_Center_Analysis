# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('noMissingData(2).csv')

# %%
df
# Out:
#     INPATIENT_DATA_ID_x DEPARTMENT_ID      DEPARTMENT_NAME  \
# 0               APTT003       DEPT001  INFUSION Department
# 1               APTT004       DEPT001  INFUSION Department
# 2               APTT008       DEPT001  INFUSION Department
# 3               APTT009       DEPT001  INFUSION Department
# 4               APTT012       DEPT001  INFUSION Department
# ..                  ...           ...                  ...
# 241             APTT419       DEPT001  INFUSION Department
# 242             APTT420       DEPT001  INFUSION Department
# 243             APTT421       DEPT001  INFUSION Department
# 244             APTT422       DEPT001  INFUSION Department
# 245             APTT423       DEPT001  INFUSION Department
#
#                     VISIT_TYPE  APPT_LENGTH APPT_STATUS_NAME CONTACT_DATE  \
# 0                INFUSION 4 HR          270          Arrived     10/31/21
# 1                INFUSION 1 HR           90        Completed     10/31/21
# ...

# %%
df['FIRST_WAIT'] = df['CHAIR_START'] - df['CHECKIN_DTTM']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ...
