# %%
from functions import convertTime
import pandas as pd
import datetime as time

# %%
df = pd.read_csv('nonDuplicateData(1).csv')

# %%
df
# Out:
#     INPATIENT_DATA_ID_x DEPARTMENT_ID      DEPARTMENT_NAME       VISIT_TYPE  \
# 0               APTT001       DEPT001  INFUSION Department  INFUSION 30 MIN
# 1               APTT002       DEPT001  INFUSION Department    INFUSION 2 HR
# 2               APTT003       DEPT001  INFUSION Department    INFUSION 4 HR
# 3               APTT004       DEPT001  INFUSION Department    INFUSION 1 HR
# 4               APTT005       DEPT001  INFUSION Department    INFUSION 2 HR
# ..                  ...           ...                  ...              ...
# 418             APTT419       DEPT001  INFUSION Department    INFUSION 2 HR
# 419             APTT420       DEPT001  INFUSION Department    INFUSION 2 HR
# 420             APTT421       DEPT001  INFUSION Department    INFUSION 1 HR
# 421             APTT422       DEPT001  INFUSION Department    INFUSION 5 HR
# 422             APTT423       DEPT001  INFUSION Department    INFUSION 2 HR
#
#      APPT_LENGTH APPT_STATUS_NAME CONTACT_DATE            APPT_DTTM  \
# 0             30          Arrived     10/31/21  2021-10-31  02:00PM
# 1            150          Arrived     10/31/21  2021-10-31  12:00PM
# 2            270          Arrived     10/31/21  2021-10-31  01:00PM
# 3             90        Completed     10/31/21  2021-10-31  09:00AM
# 4            150         Canceled     10/31/21  2021-10-31  02:00PM
# ..           ...              ...          ...                  ...
# 418          150          Arrived      11/4/21  2021-11-04  01:30PM
# 419          150        Completed      11/4/21  2021-11-04  03:30PM
# 420           90          Arrived      11/4/21  2021-11-04  01:30PM
# 421           30          Arrived      11/4/21  2021-11-04  12:00PM
# 422          150          Arrived      11/4/21  2021-11-04  04:00PM
#
#     CHECKIN_DTTM        CHECKOUT_DTTM APPT_MADE_DATE APPT_CANC_DATE  \
# 0       13:28:00                  NaN        10/3/21            NaN
# 1       12:21:00                  NaN        10/3/21            NaN
# 2       12:52:00                  NaN       10/14/21            NaN
# 3       08:50:00  2021-10-31  12:41PM        9/19/21            NaN
# 4           None                  NaN       10/24/21       10/31/21
# ..           ...                  ...            ...            ...
# 418     14:12:00                  NaN        10/5/21            NaN
# 419     14:17:00  2021-11-04  03:53PM       10/14/21            NaN
# 420     14:36:00                  NaN       10/10/21            NaN
# 421     16:13:00                  NaN       10/27/21            NaN
# 422     15:49:00                  NaN        11/4/21            NaN
#
#     CHAIR_START INFUSION_START INFUSION_END  CHAIR_OUT  \
# 0      13:40:00            NaN          NaN        NaN
# 1      13:15:00            NaN          NaN        NaN
# 2      13:15:00        1:15 PM      3:20 PM        NaN
# 3      09:20:00       11:15 AM     11:55 AM        NaN
# 4          None            NaN          NaN        NaN
# ..          ...            ...          ...        ...
# 418    14:30:00        3:45 PM      5:00 PM        NaN
# 419    14:40:00        4:00 PM      3:40 PM        NaN
# 420    14:55:00        2:15 PM      3:50 PM        NaN
# 421    16:30:00        4:45 PM      5:30 PM        NaN
# 422    16:00:00        4:51 PM          NaN        NaN
#
#                                      ORDER_DESCRIPTION  \
# 0                                                  NaN
# 1                                                  NaN
# 2               ARSENIC TRIOXIDE IN D5W/NS 250 ML IVPB
# 3                     PEMBROLIZUMAB 200 MG IN NS 59 ML
# 4                                                  NaN
# ..                                                 ...
# 418        GEMCITABINE (AS 1 G/26.3 ML) IN NS INFUSION
# 419                        VINCRISTINE IN NS INFUSION
# 420  ZOLEDRONIC ACID 4 MG/100ML IV SOLN PREMIX OVER...
# 421                        SODIUM CHLORIDE 0.9 % BOLUS
# 422               DIPHENHYDRAMINE HCL 50 MG/ML IJ SOLN
#
#                   ORDER_STATUS          CHAIR Unnamed: 19
# 0    *Unspecified Order Status        Chair 1         NaN
# 1    *Unspecified Order Status        Chair 2         NaN
# 2                Completed [5]        Chair 2         NaN
# 3                Completed [5]        Chair 3         NaN
# 4    *Unspecified Order Status        Chair 4         NaN
# ..                         ...            ...         ...
# 418                       11/4  Completed [5]     Chair 9
# 419                       11/4  Completed [5]    Chair 10
# 420                       11/4  Completed [5]    Chair 24
# 421                       11/4  Completed [5]    Chair 18
# 422                       11/4  Verified [10]     Chair 8
#
# [423 rows x 20 columns]

# %%
df['INFUSION_START'] = df['INFUSION_START'].apply(convertTime)
